# %% [markdown]
# <a href="https://colab.research.google.com/github/JUERNES360/POO_1/blob/main/explicacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Persona:

    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def mostrar_datos(self):
        print(self.nombre, self.edad)

class Estudiante(Persona):

    def __init__(self, nombre, edad, carrera):

        super().__init__(nombre, edad)

        self.carrera = carrera

    def estudiar(self):
        print(self.nombre, "está estudiando")

e1 = Estudiante("Laura", 20, "ADSO")
e1.mostrar_datos()
e1.estudiar()
